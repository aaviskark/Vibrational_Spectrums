# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# x = pd.read_excel('Acetone.xlsx')

# xval = x['cm**1']
# yval = x['Intensity']
# plt.plot(xval, yval/max(yval), label = 'Experimental Values')

plt.vlines([104.37,152.08,197,69,293.91,297.41, 313.62, 378.49, 539.09, 569.40, 601.56,654.42,698.33,711.88,718.83, 3750.69, 3762.62, 3794.87,3800.26], 0, 1, color = 'red', label = 'DFT Values')
plt.title('Tungsten(4+) tetrahydroxide IR Spectrum', size = 16)
plt.xlabel("Freqency (cm^-1)",size = 14)
plt.ylabel("Relative Absorbance", size = 14)
plt.legend(loc = 'upper right')
plt.xlim(4000, 0)
plt.ylim(0,1.25)
plt.tight_layout()
plt.savefig('./IR_H4O4W.pdf')
plt.show()
